# %% [markdown]
# # **Assessment Title:**
# # **Deep Learning Kaggle Competition: Footprint Image Classificatio**

# %% [markdown]
# # **Student Information:**
# # Write Your Name:..................
# # Write Your Student ID:............

# %% [markdown]
# # **Provide Kaggle Information**
# # Add your Kaggle Username, final score on the Kaggle provate leaderboar,and the total number of submissions you made to Kaggle.
#
# # 1. Your Kaggle Username:................
# # 2. Your final score on the Kaggle provate leaderboard:.................
# # 3. Total number of submissions you made to Kaggle:.....................

# %% [markdown]
# # **Section 1. Introduction:**
# Define the project's objective and the business case (e.g., forensic analysis). Justify why deep learning is a suitable approach for this image classification problem compared to traditional machine learning methods.

# %% [markdown]
# # Use this space to write your answer

# %% [markdown]
# # **Section 2. Exploratory Data Analysis (EDA) and Preprocessing:**
# 1. Load and analyse the image dataset. Investigate image dimensions, colour channels, class distribution, and identify any potential issues.
#
# 2. Investigate the dataset for any potential imbalances or characteristics that could introduce ethical bias into your model and document your findings.
#
# 3. Visualise sample images from each class.
#
# 4. Define, implement, and justify your data preprocessing and augmentation pipeline (e.g., resizing, normalization, rotations, flips).

# %%
#write code for Tasks
#It is recommeded to create seperate code blocks for different tasks

# %% [markdown]
# # Explain your code:

# %% [markdown]
# # **Section 3. Baseline Model (From Scratch):**
#
# 1. Design, implement, and train a simple baseline classifier architecture built entirely from scratch in PyTorch. This model must not use any pre-trained weights.
#
# 2. Evaluate its performance on a validation set and document the initial benchmark score. This model serves as the starting point for all subsequent improvements.

# %%
#write code for Tasks
#It is recommeded to create seperate code blocks for different tasks

# %% [markdown]
# # Explain your code:

# %% [markdown]
# # **Section 4. State-of-the-Art Model Analysis:**
#
# 1. Before experimenting with pre-trained models, conduct an exploratory analysis of at least three relevant vision architectures (e.g., ResNet, EfficientNet, ViT) available in libraries like torchvision.models or TIMM.
#
# 2. Compare their features, complexity (parameters, FLOPs), and suitability for this specific problem. This section serves as the "literature review" part of your report.

# %%
#write code for Tasks
#It is recommeded to create seperate code blocks for different tasks

# %% [markdown]
# # Explain your code:

# %% [markdown]
# # **Section 5. Systematic Experimentation for Model Improvement:**
#
# 1. This is the core of the assignment. You must document at least 10 distinct, well-justified experiments aimed at improving upon the baseline model's performance.
#
# 2. Each experiment must be presented as a sub-section with a clear hypothesis, implementation details, results (tables/graphs), and a concise analysis of the outcome.

# %%
#write code for Tasks
#It is recommeded to create seperate code blocks for different tasks

# %% [markdown]
# # Explain your code:

# %% [markdown]
# # **Section 6. Final Model Evaluation and Explainability (XAI):**
#
# 1. Select your single best-performing model based on the experimental results.
# 2. Provide a comprehensive performance evaluation on your validation set, including a confusion matrix, accuracy, precision, recall, and F1-score.
# 3. Apply and interpret an XAI method (e.g., Grad-CAM) on several validation images for which your model incurs the highest loss.
# 4. Beyond accuracy, critically evaluate your model's reliability. In the context of a legal investigation, what are the risks and limitations of using your model's predictions as evidence?

# %%
#write code for Tasks
#It is recommeded to create seperate code blocks for different tasks

# %% [markdown]
# # Explain you code:

# %% [markdown]
# # **Section 7. Conclusion and Reflection:**
#
# 1. Summarise the project's key findings.
# 2. Based on your analysis, would you recommend this model for deployment? What safeguards or further testing would you demand before it could be used responsibly in the real world?

# %% [markdown]
# # **Write your conclusion and reflection:**

# %% [markdown]
# # **Note for submission:**
#
# Please follow the steps below when submitting your work:
#
# 1. Download your completed notebook file in **.ipynb format**.
#
# 2. Export or save your notebook as a **PDF file**.
#
# 3. **Upload both files** — the **.ipynb file** and the **PDF** — **for submission**.
#
# **If you have any questions or face any issues, please feel free to contact or discuss them with the unit leader.**
